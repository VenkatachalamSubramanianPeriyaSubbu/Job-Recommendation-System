# %%
# !pip install transformers
# !pip install torch
# !pip install torch torchvision torchaudio

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, explode, lit, udf, struct, row_number, concat_ws, when, monotonically_increasing_id, lower, pandas_udf, array_intersect, split, size, col
from pyspark.sql.window import Window
from pyspark.ml.linalg import Vectors
from pyspark.ml.stat import Summarizer
from pyspark.sql.types import *
import numpy as np
import pandas as pd
from transformers import BertTokenizer, BertModel
import torch

# %%
# Initialize Spark Session
spark = SparkSession.builder.appName("JobMatching").getOrCreate()

# Define schema for jobs
jobs_schema = StructType([
    StructField("id", LongType(), True),
    StructField("title", StringType(), True),
    StructField("company", StringType(), True),
    StructField("location", StringType(), True),
    StructField("date", StringType(), True),
    StructField("url", StringType(), True),
    StructField("description", StringType(), True),
    StructField("salary", StringType(), True),
    StructField("source", StringType(), True),
    StructField("type", StringType(), True)
])

# Define schema for resumes, THIS DID NOT WORK
resumes_schema = StructType([
    StructField("address", StringType(), True),
    StructField("career_objective", StringType(), True),
    StructField("skills", ArrayType(StringType()), True),
    
    # Education: Nested Struct
    StructField("education", ArrayType(StructType([
        StructField("educational_institution_name", StringType(), True),
        StructField("degree_names", StringType(), True),
        StructField("passing_years", StringType(), True),
        StructField("educational_results", StringType(), True),
        StructField("result_types", StringType(), True),
        StructField("major_field_of_studies", StringType(), True)
    ])), True),

    # Experience: Nested Struct
    StructField("experience", ArrayType(StructType([
        StructField("professional_company_names", StringType(), True),
        StructField("company_urls", StringType(), True),
        StructField("start_dates", StringType(), True),
        StructField("end_dates", StringType(), True),
        StructField("related_skils_in_job", ArrayType(StringType()), True),
        StructField("positions", StringType(), True),
        StructField("locations", StringType(), True)
    ])), True),

    StructField("extracurriculars", ArrayType(StringType()), True),
    StructField("languages", ArrayType(StringType()), True),
    StructField("certifications", ArrayType(StringType()), True),
    
    StructField("job_position_name", StringType(), True),
    StructField("educationaL_requirements", StringType(), True),
    StructField("experiencere_requirement", StringType(), True),
    StructField("age_requirement", StringType(), True),
    StructField("responsibilities.1", StringType(), True),
    StructField("skills_required", StringType(), True),
    StructField("matched_score", FloatType(), True)
])


# Read JSON with predefined schema, CHANGE PATHS FOR GCP, CHANGE TO HAVE NO LIMITS I WAS HAVING COMPUTATION ISSUES
jobs_df = spark.read.schema(jobs_schema).option("multiline", "true").json("/Users/jessicalee/Downloads/jooble_jobs_all_states.json").limit(1000)
resumes_df = spark.read.option("multiline", "true").json("/Users/jessicalee/Downloads/resume_data.json")
# Out:
# 25/03/01 23:35:10 WARN Utils: Your hostname, MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 10.0.0.8 instead (on interface en0)
# 25/03/01 23:35:10 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/03/01 23:35:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
jobs_df.show(5, truncate=False)
# Out:
# +--------------------+----------------+-----------------------------+--------+---------------------------------+-------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+-----------------------+----+
# |id                  |title           |company                      |location|date                             |url                                        |description                                                                                                                                                                                                                                                                                   |salary|source                 |type|
# +--------------------+----------------+-----------------------------+--------+---------------------------------+-------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+-----------------------+----+
# |-6388373890889030877|Dental Hygienist|Johns Creek Dental Excellence|Alabama |2025-02-11T20:44:21.3702092+00:00|https://jooble.org/jdp/-6388373890889030877| Dental Hygienist \r\n$5000 Sign on Bonus plus Benefits!\r\n Johns Creek Dental Excellence  i  s seeking a part time hygenist to join their team. \r\n \r\n Why Heartland Dental?\r\n As an elite clinical provider and patient advocate, you’ll receive best in class non-clinical support...|      |jobguard.com           |    |
# |8202139045805211042 |PT              |Encompass Health             |Alabama |2025-02-12T00:00:00.0000000      |https://jooble.org/jdp/8202139045805211042 | Physical Therapist Career Opportunity \r\n  Join a Team That Puts Your Passion for Care First \r\n Are you seeking a fulfilling career that feels like home and lets you make a meaningful impact? At Encompass Health, you'll find an opportunity to provide exceptional care and...        |      |collegerecruiterCPA.com|    |
# |-8738236947968693284|LCP (Remote)    |Headway                      |Alabama |2025-02-14T00:00:00.0000000      |https://jooble.org/jdp/-8738236947968693284| LCP (Remote) at Headway summary: \r\n The position is for a Licensed Clinical Psychologist seeking to establish or grow a private practice through Headway, a platform that supports mental health clinicians. Headway assists in managing insurance billing, marketing support...           |      |jobrapido.CPA          |    |
# |3674097467795497754 |LMHC (Virtual)  |Headway                      |Alabama |2025-02-14T00:00:00.0000000      |https://jooble.org/jdp/3674097467795497754 | LMHC (Virtual) at Headway summary: \r\n The role of a Licensed Mental Health Counselor (LMHC) involves providing remote psychotherapy sessions, overseeing medication management, and growing one's private practice with the support of Headway. Counselors can maintain flexibility...     |      |jobrapido.CPA          |    |
# |3689181846594884089 |LMHT (Virtual)  |Headway                      |Alabama |2025-02-14T00:00:00.0000000      |https://jooble.org/jdp/3689181846594884089 | LMHT (Virtual) at Headway summary: \r\n As a Remote Licensed Mental Health Therapist (LMHT) with Headway, you can launch or expand your private practice while earning between $90-$127 an hour. Headway provides tools and resources for mental health practitioners to streamline...       |      |jobrapido.CPA          |    |
# +--------------------+----------------+-----------------------------+--------+---------------------------------+-------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+-----------------------+----+
# only showing top 5 rows

# %%
resumes_df.show(5, truncate=False)
# Out:
# +-------+------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------+
# |address|age_requirement   |career_objective                                                                                                                                                                                                                                                      |certifications                                             |education                                                                                                                                                                       |educationaL_requirements                                                                      |experience                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |experiencere_requirement|extracurriculars                                                                                                                                                                                                                 |languages|matched_score     |responsibilities.1                                                                                                                                                                                                                                                                                                                                                                                                     |skills                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |skills_required                                                                                                                     |﻿job_position_name                                            |
# +-------+------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------+
# |null   |null              |Big data analytics working and database warehouse manager with robust experience in handling all kinds of data. I have also used multiple cloud infrastructure services and am well acquainted with them. Currently in search of role that offers more of development.|[]                                                         |[{B.Tech, The Amity School of Engineering & Technology (ASET), Noida, N/A, Electronics, 2019, null}]                                                                            |B.Sc in Computer Science & Engineering from a reputed university.                             |[{null, Till Date, N/A, Big Data Analyst, Coca-COla, [Big Data], Nov 2019}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |At least 1 year         |[]                                                                                                                                                                                                                               |[]       |0.85              |Technical Support\nTroubleshooting\nCollaboration\nDocumentation\nSystem Monitoring\nSoftware Deployment\nTraining & Mentorship\nIndustry Trends\nField Visits\n\n\n\n\n                                                                                                                                                                                                                                               |[Big Data, Hadoop, Hive, Python, Mapreduce, Spark, Java, Machine Learning, Cloud, Hdfs, YARN, Core Java, Data Science, C++, Data Structures, DBMS, RDBMS, Informatica, Talend, Amazon Redshift, Microsoft Azure]                                                                                                                                                                                                                                                                                                      |null                                                                                                                                |Senior Software Engineer                                      |
# |null   |null              |Fresher looking to join as a data analyst and junior data scientist. Experienced in creating meaningful data dashboards and evaluation models.                                                                                                                        |[]                                                         |[{B.Sc (Maths), Delhi University - Hansraj College, N/A, Mathematics, 2015, N/A}, {M.Sc (Science) (Statistics), Delhi University - Hansraj College, N/A, Statistics, 2018, N/A}]|M.Sc in Computer Science & Engineering or in any relevant discipline from a reputed University|[{N/A, Till Date, N/A, Business Analyst, BIB Consultancy, [Data Analysis, Business Analysis, Machine Learning], Sep 2019}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |At least 5 year(s)      |[]                                                                                                                                                                                                                               |[]       |0.75              |Machine Learning Leadership\nCross-Functional Collaboration\nStrategy Development\nML/NLP Infrastructure\nPrototype Transformation\nML System Design\nAlgorithm Research\nApplication Development\nDataset Selection\nML Testing\nStatistical Analysis\nR&D in ML/NLP\nText Representation\nData Pipeline Design\nStatistical Data Analysis\nModel Training\nTeam Collaboration\nResearch Reporting\nAlgorithm Analysis|[Data Analysis, Data Analytics, Business Analysis, R, SAS, PowerBi, Tableau, Data Visualization, Business Analytics, Machine Learning]                                                                                                                                                                                                                                                                                                                                                                                |null                                                                                                                                |Machine Learning (ML) Engineer                                |
# |null   |null              |null                                                                                                                                                                                                                                                                  |[]                                                         |[{B.Tech, Birla Institute of Technology (BIT), Ranchi, N/A, Electronics/Telecommunication, 2018, N/A}]                                                                          |Master of Business Administration (MBA)                                                       |[{N/A, Till Date, N/A, Software Developer (Machine Learning Engineer), Axis Bank Limited, [Unified Payment Interface, Risk Prediction, Big Data, Spark, PySpark], June 2018}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |At least 3 years        |[]                                                                                                                                                                                                                               |[]       |0.416666667       |Trade Marketing Executive\nBrand Visibility, Sales Targets\nField Marketing, Campaigns, Product Distribution\nBrand Head\nExcel, KPIs Tracking                                                                                                                                                                                                                                                                         |[Software Development, Machine Learning, Deep Learning, Risk Assessment, Requirement Gathering, Application Support, JavaScript, Python, Docker, HTML, Hive, CSS, C, C++]                                                                                                                                                                                                                                                                                                                                             |Brand Promotion\nCampaign Management\nField Supervision\nMerchandising\npromotional activities\nTrade Marketing                     |Executive/ Senior Executive- Trade Marketing, Hygiene Products|
# |null   |Age 22 to 30 years|To obtain a position in a fast-paced business office environment, demanding a strong organizational, technical, and interpersonal position utilizing my skills and attributes.                                                                                        |[]                                                         |[{Computer Applications Specialist Certificate Program, Martinez Adult Education, Business Training Center ï¼ City , State, null, Computer Applications, 2008, null}]           |Bachelor/Honors                                                                               |[{null, November 2015, City, State, Accountant, Company Name ï¼ City , State, [accounts receivables, banking, G/L Accounts, accounts payables, credit cards, reconcile, commission reports, credit checks, customer service, international travel], January 2011}, {null, January 2010, City, State, Accounts Receivable Clerk, Company Name ï¼ City , State, [data entry, accounts receivable, cash handling, customer communication, inventory reports, problem-solving], January 2008}, {null, January 2008, City, State, Mortgage Underwriter, Company Name ï¼ City , State, [mortgage processing, analytical aptitude, credit reports, customer communication], January 2006}, {null, January 2006, City, State, Commercial Auto Underwriter, Company Name ï¼ City , State, [commercial auto underwriting, data entry, application review, customer communication], January 2004}, {null, January 2004, City, State, Personal Auto Underwriter, Company Name ï¼ City , State, [personal auto underwriting, data entry, policy review, customer service], January 2001}, {null, null, N/A, Claims Examiner, N/A, [training, medical record review, data entry, document design, customer service, team performance], N/A}]|1 to 3 years            |[]                                                                                                                                                                                                                               |[]       |0.7600000000000001|Apparel Sourcing\nQuality Garment Sourcing\nReliable Partner\nBuyer/Vendor Communication                                                                                                                                                                                                                                                                                                                               |[accounts payables, accounts receivables, Accounts Payable, Accounts Receivable, administrative functions, trial balance, banking, budget, bi, closing, Computer Applications, Credit, clients, Customer Service, data entry, delivery, driving, email, insurance, inventory, ledger, Access, Excel, Outlook, PowerPoint, Word, mortgage loan, Enterprise, policies, QuickBooks, Sales, sales reports, telecommunications, phone, workflow, written]                                                                  |Fast typing skill\nIELTSInternet browsing & online work ability.                                                                    |Business Development Executive                                |
# |null   |null              |Professional accountant with an outstanding work ethic and integrity seeking to make a valuable contribution utilizing strong analytical, organizational, communication, and computer skills.                                                                         |[{Ohio Notary Public, null, February 15, 2021, null, null}]|[{Bachelor of Business Administration, Kent State University, 3.84, Accounting, null, null}]                                                                                    |Bachelor of Science (BSc) in Computer Science                                                 |[{null, Current, City, State, Staff Accountant, Company Name, [collections, accounts receivable, financial reports, AR aging, customer queries, sales and use tax audits], January 2016}, {null, January 2016, City, State, Senior Accountant, Company Name, [financial statements, GAAP, asset, liability, capital account, accounting controls, audits], January 2016}, {null, January 2015, City, State, Tax Analyst, Company Name, [sales tax, tax returns, business licenses, annual reports, tax audits], January 2012}, {null, January 2011, City, State, Staff Accountant II, Company Name, [financial reporting, fixed assets, sales tax, cash projections, general ledger accounting], January 2009}, {null, January 2009, City, State, Staff Auditor II, Company Name, [audit procedures, substantive tests, internal accounting, tests of compliance, audit programs], January 2006}]                                                                                                                                                                                                                                                                                                                             |At least 4 years        |[{Professional Organization, null, Ohio Society of CPAs, null}, {Honor Society, null, Beta Alpha Psi, null}, {Honor Society, null, Golden Key International Honour Society, null}, {Honor Society, null, Beta Gamma Sigma, null}]|[]       |0.65              |iOS Lifecycle\nRequirement Analysis\nNative Frameworks\niOS Development\nAPI Integration\nTechnical Communication\nUI Design\nPerformance Optimization\nFeature Collaboration\nBug Fixing\nCode Translation\nHigh-Performance Development\nTask Management\nCross-Team Collaboration\nCode Quality                                                                                                                     |[Analytical reasoning, Compliance testing knowledge, Effective time management, Public and private accounting, accounting, accounting systems, accounts payable, accounts receivable, administrative, AR, billing, closing, client, clients, documentation, financial, financial reports, preparation of financial reports, Preparation of financial statements, fixed assets, managing, month-end closing, policies, maintain records, reporting, Research, sales, tax, taxes, tax returns, annual reports, year-end]|iOS\niOS App Developer\niOS Application Development\niOS Development\nMobile apps Developer (iOS)\nNative IOS\nSwift (iOS)\nSwift UI|Senior iOS Engineer                                           |
# +-------+------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------+
# only showing top 5 rows

# %%
# Rename the incorrect column
resumes_df = resumes_df.withColumnRenamed("﻿job_position_name", "job_position_name")

# Now check if it works
resumes_df.select("job_position_name").show(5, truncate=False)
# Out:
# +--------------------------------------------------------------+
# |job_position_name                                             |
# +--------------------------------------------------------------+
# |Senior Software Engineer                                      |
# |Machine Learning (ML) Engineer                                |
# |Executive/ Senior Executive- Trade Marketing, Hygiene Products|
# |Business Development Executive                                |
# |Senior iOS Engineer                                           |
# +--------------------------------------------------------------+
# only showing top 5 rows

# %%
filtered_resumes_df = resumes_df.filter(col("matched_score") > 0.85)

filtered_resumes_df.count()
# Out:
# 161

# %%
filtered_resumes_df.printSchema()
# Out:
# root
#  |-- address: string (nullable = true)
#  |-- age_requirement: string (nullable = true)
#  |-- career_objective: string (nullable = true)
#  |-- certifications: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- certification_providers: string (nullable = true)
#  |    |    |-- certification_skills: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- expiry_dates: string (nullable = true)
#  |    |    |-- issue_dates: string (nullable = true)
#  |    |    |-- online_links: string (nullable = true)
#  |-- education: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- degree_names: string (nullable = true)
#  |    |    |-- educational_institution_name: string (nullable = true)
#  |    |    |-- educational_results: string (nullable = true)
#  |    |    |-- major_field_of_studies: string (nullable = true)
#  |    |    |-- passing_years: string (nullable = true)
#  |    |    |-- result_types: string (nullable = true)
#  |-- educationaL_requirements: string (nullable = true)
#  |-- experience: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- company_urls: string (nullable = true)
#  |    |    |-- end_dates: string (nullable = true)
#  |    |    |-- locations: string (nullable = true)
#  |    |    |-- positions: string (nullable = true)
#  |    |    |-- professional_company_names: string (nullable = true)
#  |    |    |-- related_skils_in_job: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- start_dates: string (nullable = true)
#  |-- experiencere_requirement: string (nullable = true)
#  |-- extracurriculars: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- extra_curricular_activity_types: string (nullable = true)
#  |    |    |-- extra_curricular_organization_links: string (nullable = true)
#  |    |    |-- extra_curricular_organization_names: string (nullable = true)
#  |    |    |-- role_positions: string (nullable = true)
#  |-- languages: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- languages: string (nullable = true)
#  |    |    |-- proficiency_levels: string (nullable = true)
#  |-- matched_score: double (nullable = true)
#  |-- responsibilities.1: string (nullable = true)
#  |-- skills: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- skills_required: string (nullable = true)
#  |-- job_position_name: string (nullable = true)

# %%
# Ensure job_position_name is correctly named
filtered_resumes_df = filtered_resumes_df.withColumnRenamed("﻿job_position_name", "job_position_name")

# Split job titles and positions into word arrays
jobs_df = jobs_df.withColumn("title_words", split(col("title"), " "))
filtered_resumes_df = filtered_resumes_df.withColumn("position_words", split(col("job_position_name"), " "))

# Perform cross join between jobs and resumes
jobs_resumes_df = jobs_df.crossJoin(filtered_resumes_df)

# Compute word overlap between job titles and resume positions
jobs_resumes_df = jobs_resumes_df.withColumn("word_overlap", array_intersect(col("title_words"), col("position_words")))

# Filter jobs where at least one word overlaps
similar_jobs_df = jobs_resumes_df.filter(size(col("word_overlap")) > 0)

# Count the number of similar jobs
similar_jobs_count = similar_jobs_df.count()
print(f"Number of similar jobs found: {similar_jobs_count}")

# Create a filtered jobs DataFrame containing only the relevant columns
filtered_jobs_df = similar_jobs_df.select(
    "id", "title", "company", "location", "date", "url", "description", "salary", "source", "type"
).distinct()

# Show the filtered jobs
filtered_jobs_df.count()
# Out:
# Number of similar jobs found: 10291
# 509

# %%
# Assign unique ID to each candidate
resumes_df = filtered_resumes_df.withColumn("candidate_id", monotonically_increasing_id())
jobs_df = filtered_jobs_df.fillna("")
resumes_df = resumes_df.fillna("Unknown Position", subset=["job_position_name"])
jobs_df = jobs_df.withColumn("title", lower(col("title")))
resumes_df = resumes_df.withColumn("job_position_name", lower(col("job_position_name")))
resumes_df = resumes_df.withColumnRenamed("responsibilities.1", "responsibilities_1")
resumes_df = resumes_df.withColumn("skills_text", concat_ws(" ", col("skills")))
resumes_df.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+------------------------+--------------------+------------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+
# |             address|     age_requirement|    career_objective|      certifications|           education|educationaL_requirements|          experience|experiencere_requirement|    extracurriculars|           languages|     matched_score|  responsibilities_1|              skills|     skills_required|   job_position_name|      position_words|candidate_id|         skills_text|
# +--------------------+--------------------+--------------------+--------------------+--------------------+------------------------+--------------------+------------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+
# |160 Bleecker Stre...|                null|                null|                  []|[{PhD Candidate, ...|    M.Sc in Computer ...|[{null, null, New...|      At least 5 year(s)|[{Volunteering, n...|[{English, Fluent...|       0.893333333|Machine Learning ...|[Game Theory, Bou...|                null|machine learning ...|[Machine, Learnin...|           0|Game Theory Bound...|
# |                null|                null|Expertise EDA mod...|                  []|[{B.CA, KVoCT, Pu...|    M.Sc in Computer ...|[{null, Ongoing, ...|      At least 5 year(s)|                  []|                  []|       0.943333333|Machine Learning ...|[Data Analysis, B...|                null|machine learning ...|[Machine, Learnin...|           1|Data Analysis Bus...|
# |                null|  Age 25 to 35 years|I am looking for ...|[{ITIL, null, nul...|[{Bachelor of Eng...|    Diploma, Bachelor...|[{null, January 2...|        At least 3 years|                  []|                  []|       0.873333333|Mikrotik Router C...|[active directory...|CCNA (Cisco Certi...|network support e...|[Network, Support...|           2|active directory ...|
# |                null|                null|Currently seeking...|                  []|[{B.Tech, Cummins...|    Bachelors or Mast...|[{N/A, Aug 2020, ...|                    null|[{Award, N/A, L&T...|                  []|       0.883333333|Machine Learning ...|[Data science, De...|Python\nR or Java...|         ai engineer|      [AI, Engineer]|           3|Data science Deep...|
# |                null|                null|A quality-oriente...|                  []|[{B.Tech, Lucknow...|         Bachelor/Honors|[{N/A, Apr 2021, ...|            3 to 7 years|                  []|                  []|              0.95|Full Stack Develo...|[Data Science, Ma...|                null|full stack develo...|[Full, Stack, Dev...|           4|Data Science Mach...|
# |                null|  Age 25 to 40 years|                null|                  []|[{B.S, McFord Uni...|    Bachelor of Scien...|[{null, January 2...|         At least 1 year|[{Volunteering, n...|                  []|       0.873333333|Database Design &...|[Operations manag...|ASP.NET MVC Stron...|database administ...|[Database, Admini...|           5|Operations manage...|
# |                null|Age at least 28 y...|Experienced produ...|[{Management Lead...|[{Bachelor of Sci...|         Bachelor/Honors|[{null, Current, ...|        At least 5 years|                  []|                  []|       0.883333333|Administrative Su...|[Microsoft Office...|•Administration\n...|asst. manager/ ma...|[Asst., Manager/,...|          17|Microsoft Office ...|
# |                null|Age at most 52 years|Professional acco...|[{Ohio Notary Pub...|[{Bachelor of Bus...|    Masters, Master o...|[{null, Current, ...|       At least 15 years|[{Professional Or...|                  []|0.9366666666666666|15+ Years Banking...|[Analytical reaso...|AUDIT AND INSPECT...|head of internal ...|[Head, of, Intern...|          18|Analytical reason...|
# |                null|                null|                null|[{Military, [Mili...|[{Bachelor of Sci...|    Bachelor of Scien...|[{null, Current, ...|        At least 4 years|                  []|                  []|0.8833333333333333|iOS Lifecycle\nRe...|[Superior attenti...|iOS\niOS App Deve...| senior ios engineer|[Senior, iOS, Eng...|          19|Superior attentio...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+------------------------+--------------------+------------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+
# only showing top 20 rows

# %%
# Load BERT tokenizer & model once (avoiding reloading in each row)
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")
model.eval()

# Define Pandas UDF for efficient BERT embedding computation
@pandas_udf(ArrayType(FloatType()))
def bert_pandas_udf(text_series: pd.Series) -> pd.Series:
    """Computes BERT embeddings in parallel using Pandas UDF."""
    embeddings = []
    for text in text_series:
        if text is None or text.strip() == "":
            embeddings.append([0.0] * 768)  # Return zero vector for missing text
        else:
            tokens = tokenizer(text, padding='max_length', truncation=True, max_length=128, return_tensors="pt")
            with torch.no_grad():
                output = model(**tokens)
            embeddings.append(output.last_hidden_state.mean(dim=1).squeeze().tolist())
    return pd.Series(embeddings)

# Apply BERT embeddings efficiently
jobs_df = jobs_df.withColumn("bert_description", bert_pandas_udf(col("description")))
resumes_df = resumes_df.withColumn("bert_career_objective", bert_pandas_udf(col("career_objective")))
resumes_df = resumes_df.withColumn("bert_skills", bert_pandas_udf(col("skills_text")))
resumes_df = resumes_df.withColumn("bert_responsibilities", bert_pandas_udf(col("responsibilities_1")))

# Check results
jobs_df.select("description", "bert_description").show(5, truncate=False)
resumes_df.select("career_objective", "bert_career_objective").show(5, truncate=False)

# Define cosine similarity function as UDF
@pandas_udf(FloatType())
def cosine_similarity(vec1_series: pd.Series, vec2_series: pd.Series) -> pd.Series:
    """Computes cosine similarity between two BERT vectors."""
    similarities = []
    for vec1, vec2 in zip(vec1_series, vec2_series):
        if vec1 is None or vec2 is None:
            similarities.append(0.0)
        else:
            vec1 = np.array(vec1)
            vec2 = np.array(vec2)
            dot_product = np.dot(vec1, vec2)
            norm_a = np.linalg.norm(vec1)
            norm_b = np.linalg.norm(vec2)
            similarity = float(dot_product / (norm_a * norm_b)) if norm_a and norm_b else 0.0
            similarities.append(similarity)
    return pd.Series(similarities)

# Cross join resumes with jobs (matching all candidates with all jobs)
cross_df = resumes_df.crossJoin(jobs_df)

# Compute similarity scores using different resume components
cross_df = cross_df.withColumn("description_match", cosine_similarity(col("bert_description"), col("bert_career_objective")))
cross_df = cross_df.withColumn("skills_match", cosine_similarity(col("bert_description"), col("bert_skills")))
cross_df = cross_df.withColumn("responsibilities_match", cosine_similarity(col("bert_responsibilities"), col("bert_career_objective")))

# Compute final match score using weighted average
cross_df = cross_df.withColumn("match_score", 
    (col("description_match") * 0.4 + 
     col("skills_match") * 0.4 + 
     col("responsibilities_match") * 0.2)
)

# Rank jobs for each candidate
window_spec = Window.partitionBy("candidate_id").orderBy(col("match_score").desc())
cross_df = cross_df.withColumn("rank", row_number().over(window_spec))

# Select top 10 matches per candidate
top_matches_df = cross_df.filter(col("rank") <= 10)

# Select relevant columns and display results
final_results = top_matches_df.select("candidate_id", "id", "title", "company", "match_score")
final_results.show(20, truncate=False)  # Show more results
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# |description                                                                                                                                                                                                                                                                                       |bert_description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# | Hi,  \r\n  Hope you are doing well,  \r\n  Please find the job description given below and let me know your interest.  \r\n  Position:  Apriso Developer (100% Remote) \r\n  Location: 100% Remote  \r\n  Duration : 6+ months  \r\n  Job Description  :  \r\n  About the job  \r\n  They must...|[0.10191162, 0.044019252, 0.17720379, 0.029745972, 0.27352703, -0.16080768, 0.14426365, 0.47718644, 0.105634384, -0.18498066, -0.108511254, -0.07942672, 0.15624633, 0.14565685, -0.022132896, 0.21945049, 0.09921339, 0.2258421, -0.026822906, 0.22311574, 0.07140542, -0.085728504, 0.07517235, 0.1096798, 0.38791004, 0.041109912, -0.11345046, 0.005802978, -0.24129584, -0.13694023, 0.058556996, -0.18262891, 0.0607721, -0.08384444, 0.029589396, -0.1207501, -0.048197523, 0.16901705, 0.020246375, -0.06522831, -0.3031773, -0.20089461, 0.27873617, 0.009242976, -0.25438043, -0.32878074, -0.055720106, -0.22463147, -0.07501952, 0.036996197, -0.28174883, 0.16128272, -0.069779545, -0.14812097, 0.028142963, 0.36132, 0.1807448, -0.4985095, -0.543899, -0.11051932, 0.25917202, -0.14313868, 0.046266094, -0.18966784, 0.3187918, 0.1749836, 0.3250161, 0.20716119, -0.27410567, 0.18149054, -0.03069622, -0.120737955, -0.10096209, 0.0611808, -0.16994582, -0.018582892, -0.052291345, 0.23003654, 0.14308707, 0.03088503, -0.06560223, 0.26592758, -0.090408586, 0.052384485, 0.09398852, 0.008947758, 0.22042993, 0.04875909, -0.26625213, 0.4601602, 0.29723954, -0.15355353, 0.11563117, -0.034393303, 0.32566163, -0.41124684, 0.0681307, 0.09461316, -0.34951028, 0.07046693, -0.03955297, -0.14840443, -0.04288896, -0.039033838, -0.18057184, 0.12063337, 0.29530635, 0.063087106, -0.12468956, 0.44826168, -0.055223305, 0.0656969, 0.047309197, -0.1684636, -0.13890946, 0.10661995, 0.117526606, 0.07444507, -0.00640349, 0.23913373, -0.059947435, 0.14734168, -0.092123024, 0.52393156, -0.021515213, 0.120552815, -0.12876627, 0.043985534, -0.122717574, -0.32112595, 0.27140328, 0.110721454, 0.143545, -0.06114318, 0.058635652, -0.016966078, -0.17128375, -0.21179132, -0.07825163, -0.10858414, -0.14126755, -0.10145508, 0.
 0.076576054, -0.2886403, -0.27967653, 0.16396202, -0.18570854, -0.42255282, 0.22537413, -0.03340131, 0.47741205, 0.20953047, 0.017792702, -0.062302366, 0.11099371, -0.10715413, -0.007406149, -0.34129986, 0.038034618, 0.043899704, -0.12029133, 0.012289672, -0.368695, -0.1619401, 0.07041594, -0.09403627, 0.038579956, -0.121174745, 0.11267564, 0.100757, -0.20505069, 0.0011217538, -0.48212558, -0.07034502, -0.2982517, 0.3825521, 0.23826072, 6.752312E-4, -0.011131113, -0.006011676, 0.5932212, -0.15122509, -0.4955596, 0.20906952, -0.06642769, -0.0055669434, -0.11726441, 0.14463232, 0.46733835, -0.33301717, 0.022770546, 0.07986231, -0.033126965, 0.11957657, -0.1803715, -0.11023694, -0.06553513, 0.010291524, 0.10461816, -0.2812876, -0.22585028, 0.6066822, 0.18080866, 0.039 ...
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 5 rows
# [Stage 36:>                                                         (0 + 1) / 1]
# +------------+--------------------+--------------------------------------------+--------------------------+-------------------+
# |candidate_id|id                  |title                                       |company                   |match_score        |
# +------------+--------------------+--------------------------------------------+--------------------------+-------------------+
# |0           |-2799453903882674470|esri arcgis developer position,             |VRK IT Vision Inc         |0.2904040813446045 |
# |0           |-7951924925996019256|senior product designer                     |Areeb Technology          |0.2866989135742188 |
# |0           |9015025195259599841 |sr netsuite developer                       |Programmers.io            |0.28428475856781005|
# |0           |-1876203384188212130|process technician - injection molding      |Zobility                  |0.2802561044692993 |
# |0           |-2286799324781684881|automation engineer                         |Tekaccel Inc              |0.2782281875610352 |
# |0           |-3095855200821174782|project manager (public safety applications)|VDart Inc                 |0.27598950862884525|
# |0           |6712516878358918834 |ofsaa ecm developer                         |Tekaccel Inc              |0.27470457553863525|
# |0           |7488318177088643435 |data engineer                               |Hierarch Soft             |0.2746120929718018 |
# |0           |-4176383328742316483|technical program manager - remote          |Beth Page tech            |0.2746069192886353 |
# |0           |2676219568923397897 |software engineer                           |Camgian Corporation       |0.27432343959808353|
# |6           |-6999912574959420811|senior structural engineer                  |Thomas Talent Network LLC |0.789998233318329  |
# |6           |-4400036501808637627|technical writer - psur consultant          |United Consulting Hub     |0.7857938885688782 |
# |6           |8932024024939652442 |sales consultant - landscaping              |Rentokil Initial          |0.7819850087165834 |
# |6           |4001685666987236756 |environmental health & safety manager       |Qwerkz                    |0.7765055537223817 |
# |6           |3199732265140403949 |cnp associate - mves - 2/5/2025             |Alabaster City Schools    |0.7753572583198548 |
# |6           |3683362780814897036 |custodian - ths - apply 2/5/2025            |Alabaster City Schools    |0.7712246060371399 |
# |6           |8140938833364402667 |process engineer                            |Zobility                  |0.7674737095832825 |
# |6           |-6181319221161396717|cosmetology / barber instructor             |Brown Beauty Barber School|0.766462290287018  |
# |6           |-6548850438175290988|maintenance director                        |Crowne Health Care        |0.7661409735679627 |
# |6           |-3095855200821174782|project manager (public safety applications)|VDart Inc                 |0.7660191416740418 |
# +------------+--------------------+--------------------------------------------+--------------------------+-------------------+
# only showing top 20 rows

# %%
spark.stop()
